# %% [markdown]
# # Real Estate Scraper - Exploration Notebook
#
# This notebook is used for:
# - Testing scraping logic
# - Inspecting HTML structure of Immovlan listings
# - Debugging selectors
# - Validating parsed property data
# - Quick analysis of scraped samples

# %% [markdown]
# ### Install the libraries first by running
# pip install -r requirements.txt

# %%
# You can test your work here
